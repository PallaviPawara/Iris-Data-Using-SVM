# %% [markdown]
# #### Import Pandas Library :

# %%
import pandas as pd

# %% [markdown]
# #### Load Iris_Dataset :

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %% [markdown]
# #### View all rows and columns :

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# #### Display names 0f Features in Iris Data :

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# #### Display names of Target in Iris Dataset :

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# #### Display Data present in Iris data :

# %%
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
df = pd.DataFrame(iris.data , columns = iris.feature_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# #### View only first 5 rows :

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# #### Add Target column to our (df) Dataframe :

# %%
df['target'] = iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# #### Check Target Value count  :

# %%
df.target.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: target, dtype: int64

# %%
df[df.target == 0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df[df.target == 1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df[df.target == 2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target
# 100       2
# 101       2
# 102       2
# 103       2
# 104       2

# %% [markdown]
# #### Add new column Flower_name using Lamda Function :

# %%
df['Flower_name'] = df.target.apply(lambda x : iris.target_names[x])

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target Flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %% [markdown]
# #### Create DataFrame for Setosa :

# %%
df0 = df[ : 50]

# %%
df0.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target Flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %% [markdown]
# #### Create DataFrame for Versicolor :

# %%
df1 = df[50 : 100]

# %%
df1.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target Flower_name
# 50       1  versicolor
# 51       1  versicolor
# 52       1  versicolor
# 53       1  versicolor
# 54       1  versicolor

# %% [markdown]
# #### Create DataFrame for Verginica :

# %%
df2 = df[100 : ]

# %%
df2.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target Flower_name
# 100       2   virginica
# 101       2   virginica
# 102       2   virginica
# 103       2   virginica
# 104       2   virginica

# %% [markdown]
# #### View Some Visualisations :

# %% [markdown]
# #### Import Matplotlib Labrary :

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Setosa V/S Vergicolor :
# #### Sepal length V/S Sepal width :

# %%
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Length')
plt.scatter(df0['sepal length (cm)'] , df0['sepal width (cm)'] , color = "green" , marker = '+')
plt.scatter(df1['sepal length (cm)'] , df1['sepal width (cm)'] , color = "blue" , marker = '.')

# %% [markdown]
# #### Petal length V/S Petal width :

# %%
plt.xlabel('Petal Length')
plt.ylabel('Petal Length')
plt.scatter(df0['petal length (cm)'] , df0['petal width (cm)'] , color = "green" , marker = '+')
plt.scatter(df1['petal length (cm)'] , df1['petal width (cm)'] , color = "blue" , marker = '.')

# %% [markdown]
# #### Split data into Train and Test :

# %%
x = df.drop(['target' , 'Flower_name'], axis = "columns")
y = df.target

# %%
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2)

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %% [markdown]
# #### Import SVM from sklearn Library :

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(x_train , y_train)
# Out:
# SVC()

# %%
model.score(x_train , y_train)
# Out:
# 0.975

# %%
model.predict([[4.8 , 3.0, 1.5 , 0.3]])
# Out:
# array([0])

# %%
model.score(x_test , y_test)
# Out:
# 1.0

# %% [markdown]
# ### Tune Parameters :

# %% [markdown]
# #### 1] Regularization(C) :

# %%
model_c = SVC(C = 1)

# %%
model_c.fit(x_train , y_train)
# Out:
# SVC(C=1)

# %%
model_c.score(x_test , y_test)
# Out:
# 1.0

# %%
model_c = SVC(C = 10)

# %%
model_c.fit(x_train , y_train)
# Out:
# SVC(C=10)

# %%
model_c.score(x_test , y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# #### 2] Gamma :

# %%
model_g = SVC(gamma = 10)

# %%
model_g.fit(x_train , y_train)
# Out:
# SVC(gamma=10)

# %%
model_g.score(x_test , y_test)
# Out:
# 0.9

# %% [markdown]
#  #### 3] Kernel :

# %%
model_linear_kernel = SVC(kernel = "linear")

# %%
model_linear_kernel.fit(x_train , y_train)
# Out:
# SVC(kernel='linear')

# %%
model_linear_kernel.score(x_test , y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# #### .................................................................. End..............................................................

# %% [markdown]
# #### ....................................................Thank You...............................................................
